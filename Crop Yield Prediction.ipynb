# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %% [markdown]
# ## Data Exploration and Cleaning

# %%
# import data
df = pd.read_csv('yield_df.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
# drop unanamed column
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
# check for null values
df.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
# check for duplicate rows
df.duplicated().sum()
# Out:
# 2310

# %%
# drop duplicates
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# dimension of dataframe
df.shape
# Out:
# (25932, 7)

# %% [markdown]
# #### Statistical Summary

# %%
df.describe()
# Out:
#                Year    hg/ha_yield  average_rain_fall_mm_per_year  \
# count  25932.000000   25932.000000                   25932.000000
# mean    2001.556455   76978.132925                    1146.836688
# std        7.055924   84647.605552                     717.391098
# min     1990.000000      50.000000                      51.000000
# 25%     1995.000000   19996.000000                     593.000000
# 50%     2001.000000   39530.000000                    1083.000000
# 75%     2008.000000  104168.000000                    1668.000000
# max     2013.000000  501412.000000                    3240.000000
#
#        pesticides_tonnes      avg_temp
# count       25932.000000  25932.000000
# mean        34782.573241     20.422251
# std         57228.568244      6.439402
# min             0.040000      1.300000
# 25%          1597.000000     16.580000
# 50%         15373.000000     21.420000
# 75%         45620.000000     26.060000
# max        367778.000000     30.650000

# %%
df.corr(numeric_only=True)
# Out:
#                                    Year  hg/ha_yield  \
# Year                           1.000000     0.091327
# hg/ha_yield                    0.091327     1.000000
# average_rain_fall_mm_per_year -0.006423    -0.004067
# pesticides_tonnes              0.135127     0.065523
# avg_temp                       0.013701    -0.110400
#
#                                average_rain_fall_mm_per_year  \
# Year                                               -0.006423
# hg/ha_yield                                        -0.004067
# average_rain_fall_mm_per_year                       1.000000
# pesticides_tonnes                                   0.161483
# avg_temp                                            0.333694
#
#                                pesticides_tonnes  avg_temp
# Year                                    0.135127  0.013701
# hg/ha_yield                             0.065523 -0.110400
# average_rain_fall_mm_per_year           0.161483  0.333694
# ...

# %% [markdown]
# #### Check Number of Unique Values

# %%
df.nunique()
# Out:
# Area                               101
# Item                                10
# Year                                23
# hg/ha_yield                      11514
# average_rain_fall_mm_per_year      100
# pesticides_tonnes                 1673
# avg_temp                          1831
# dtype: int64

# %%
df['Item'].value_counts()
# Out:
# Item
# Potatoes                3956
# Maize                   3824
# Wheat                   3539
# Rice, paddy             3091
# Soybeans                2940
# Sorghum                 2770
# Sweet potatoes          2593
# Cassava                 1889
# Yams                     774
# Plantains and others     556
# Name: count, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(15,20))
sns.countplot(y = 'Area',data=df)
plt.show()

# %%
# Create a count plot
plt.figure(figsize=(15, 20))
ax = sns.countplot(y='Area', data=df)
ax.set(title="Count Plot of Countries(Area)", xlabel="Count", ylabel="Area")

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(y='Item', data=df)
ax.set(title="Count Plot of Food Items", xlabel="Count", ylabel="Item")

# Show the plot
plt.show()

# %%
# yield per country
country = df['Area'].unique()
yield_per_country = []
for state in country:
    yield_per_country.append(df[df['Area'] == state]['hg/ha_yield'].sum())

# %%
yield_per_country
# Out:
# [5711536,
#  6711464,
#  5722563,
#  32864032,
#  4524100,
#  109111062,
#  10852258,
#  4608380,
#  4384717,
#  4443889,
#  7720159,
#  4704812,
#  8442270,
#  470651,
#  136340329,
#  6263075,
#  6083337,
#  7031146,
#  10717883,
#  34706922,
#  4255627,
#  20561214,
#  26927138,
#  6083167,
#  10701651,
#  25312166,
#  21315591,
#  36828848,
#  16855944,
#  1452416,
#  3595638,
#  6210668,
#  15790618,
#  38780463,
#  9260371,
#  14571925,
#  16508723,
#  7975743,
#  8361103,
#  8619194,
#  10920131,
#  8824110,
#  274219558,
#  68067328,
#  10984722,
#  9104030,
#  32280700,
#  19698007,
#  100924145,
#  9965212,
#  14391737,
#  3698588,
#  6956804,
#  4258932,
#  9016288,
#  4174348,
#  6103523,
#  8346715,
#  7934982,
#  15106720,
#  4465841,
#  12684212,
#  113698872,
#  1645100,
#  22173010,
#  6964027,
#  3165475,
#  4113713,
#  14086433,
#  17657728,
#  12819227,
#  12316327,
#  6721305,
#  49264956,
#  10729929,
#  15201910,
#  6564711,
#  12154347,
#  5995626,
# ...

# %%
plt.figure(figsize=(15,20))
sns.barplot(y = country, x = yield_per_country)
plt.show()

# %%
# yield per crop
crops = df['Item'].unique()
yield_per_crop = []
for crop in crops:
    yield_per_crop.append(df[df['Item'] == crop]['hg/ha_yield'].sum())

# %%
plt.figure(figsize=(10, 10))
ax = sns.barplot(y = crops, x = yield_per_crop)
ax.set(title="Yield of Crops", xlabel="Yield", ylabel="Crop")

# Show the plot
plt.show()

# %% [markdown]
# ## Machine Learning

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %% [markdown]
# Scale and Transform Data

# %%
df.columns
# Out:
# Index(['Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
col = ['Year','average_rain_fall_mm_per_year','pesticides_tonnes', 'avg_temp','Area', 'Item', 'hg/ha_yield']
df = df[col]
df.head()
# Out:
#    Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp     Area  \
# 0  1990                         1485.0              121.0     16.37  Albania
# 1  1990                         1485.0              121.0     16.37  Albania
# 2  1990                         1485.0              121.0     16.37  Albania
# 3  1990                         1485.0              121.0     16.37  Albania
# 4  1990                         1485.0              121.0     16.37  Albania
#
#           Item  hg/ha_yield
# 0        Maize        36613
# 1     Potatoes        66667
# 2  Rice, paddy        23333
# 3      Sorghum        12500
# 4     Soybeans         7000

# %%
X = df.drop('hg/ha_yield', axis = 1)
y = df['hg/ha_yield']

# %%
X.shape, y.shape
# Out:
# ((25932, 6), (25932,))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)

# %%
ohe = OneHotEncoder(drop = 'first')
scale = StandardScaler()

preprocesser = ColumnTransformer(
    transformers = [
        ('StandardScale', scale, [0,1,2,3]),
        ('OneHotEncode', ohe, [4,5])
    ], 
    remainder = 'passthrough'
)

# %%
X_train_tf = preprocesser.fit_transform(X_train)
X_test_tf  = preprocesser.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression,Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
# Dictionary of models
models = {
    'Linear Regression': LinearRegression(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'Decision Tree': DecisionTreeRegressor(),
    'KNN': KNeighborsRegressor(),
}

# List to hold model performance data
performance_metrics = []

# Loop through models and calculate metrics
for name, md in models.items():
    md.fit(X_train_tf, y_train)
    y_pred = md.predict(X_test_tf)
    
    # Calculate metrics
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    # Append model performance data to the list
    performance_metrics.append({
        'Model': name,
        'MAE': mae,
        'R²': r2
    })

# Convert the list of dictionaries into a DataFrame
performance_df = pd.DataFrame(performance_metrics)

performance_df
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:639: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 67280771830.03516, tolerance: 14848622817.505228
#                Model           MAE        R²
# 0  Linear Regression  29897.285053  0.747273
# 1              Lasso  29883.830652  0.747294
# 2              Ridge  29851.465447  0.747265
# 3      Decision Tree   5507.057451  0.970124
# 4                KNN   4693.985772  0.984519

# %%
# Sort the DataFrame by R² in descending order
performance_df.sort_values(by='R²', ascending=False)
# Out:
#                Model           MAE        R²
# 4                KNN   4693.985772  0.984519
# 3      Decision Tree   5507.057451  0.970124
# 1              Lasso  29883.830652  0.747294
# 0  Linear Regression  29897.285053  0.747273
# 2              Ridge  29851.465447  0.747265

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train_tf,y_train)
dt_model.predict(X_test_tf)
# Out:
# array([35286., 22814., 19295., ..., 11488., 34879., 77391.])

# %% [markdown]
# Create prediction function

# %%
def prediction(Year, average_rain_fall_mm_per_year,pesticides_tonnes, avg_temp, Area, Item):
    features = np.array([[Year, average_rain_fall_mm_per_year,pesticides_tonnes, avg_temp, Area, Item]], dtype = object)
    transform_features = preprocesser.transform(features)
    predicted_yield = dt_model.predict(transform_features).reshape(-1,1)
    return predicted_yield[0][0]

# %%
prediction(1990,1485.0,121.0,16.37,'Albania','Maize')
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but OneHotEncoder was fitted with feature names
# 36613.0

# %%
# save model
import pickle
pickle.dump(dt_model, open("dt_model.pkl","wb"))
pickle.dump(preprocesser, open("preprocesser.pkl","wb"))
